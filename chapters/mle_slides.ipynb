# %%
# %%html
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path.append("..")
import statnlpbook.util as util
import statnlpbook.mle as smle
from statnlpbook.util import safe_log as log
util.execute_notebook('mle.ipynb')

# %% [markdown]
# <!---
# Latex Macros
# -->
# $$
# \newcommand{\Xs}{\mathcal{X}}
# \newcommand{\Ys}{\mathcal{Y}}
# \newcommand{\y}{\mathbf{y}}
# \newcommand{\balpha}{\boldsymbol{\alpha}}
# \newcommand{\bbeta}{\boldsymbol{\beta}}
# \newcommand{\aligns}{\mathbf{a}}
# \newcommand{\align}{a}
# \newcommand{\source}{\mathbf{s}}
# \newcommand{\target}{\mathbf{t}}
# \newcommand{\ssource}{s}
# \newcommand{\starget}{t}
# \newcommand{\repr}{\mathbf{f}}
# \newcommand{\repry}{\mathbf{g}}
# \newcommand{\x}{\mathbf{x}}
# \newcommand{\prob}{p}
# \newcommand{\a}{\alpha}
# \newcommand{\b}{\beta}
# \newcommand{\vocab}{V}
# \newcommand{\params}{\boldsymbol{\theta}}
# \newcommand{\param}{\theta}
# \DeclareMathOperator{\perplexity}{PP}
# \DeclareMathOperator{\argmax}{argmax}
# \DeclareMathOperator{\argmin}{argmin}
# \newcommand{\train}{\mathcal{D}}
# \newcommand{\counts}[2]{\#_{#1}(#2) }
# \newcommand{\length}[1]{\text{length}(#1) }
# \newcommand{\indi}{\mathbb{I}}
# \newcommand{\china}{\text{China}}
# \newcommand{\mexico}{\text{Mexico}}
# \newcommand{\paramc}{\param_\china}
# \newcommand{\paramm}{\param_\mexico}
# \newcommand{\countc}{\counts{\train}{\china}}
# \newcommand{\countm}{\counts{\train}{\mexico}}
# $$

# %% [markdown]
# # Maximum Likelihood Estimation
# for **ShallowDrumpf**!

# %% [markdown]
# What does
# $$
# \argmax_\params \sum_{(\x,\y) \in \train} \log \prob_\params(\x,\y)
# $$
# have to do with counting?

# %% [markdown]
# ## Application: ShallowDrumpf
#
# Develop **unigram language model** for generating simplified Trump speeches
#
# > China, China, China, Mexico, China, Mexico ...

# %% [markdown]
# ## Model
#
# $$
# \prob_\params(w) = \params_w
# $$
#
# $$
# \prob_\params(\text{China}) = \params_\text{China}  \qquad \prob_\params(\text{Mexico}) = \params_\text{Mexico}
# $$

# %%
m = "Mexico"
c = "China"
def prob(th_china, th_mexico, word):
    return th_china if word == 'China' else th_mexico

prob(0.7, 0.3, 'China')
# Out:
# 0.7

# %% [markdown]
# ## Maximum Likelihood Objective
#
# $$
# l(\params) = \sum_{w \in \train} \log \prob_\params(w)
# $$

# %% [markdown]
# $$
# l(\params)  = \countc  \log \paramc +  \countm \log \paramm
# $$

# %% [markdown]
# Solution is **counting**:
#
# $$
# \paramc = \frac{\countc}{\countc + \countm}
# $$

# %%
def mle(data):
    theta_china = len([w for w in data if w == 'China']) / len(data)
    return theta_china, 1.0 - theta_china 

mle([c,c,m,c])
# Out:
# (0.75, 0.25)

# %% [markdown]
# ### Loss  Surface

# %%
def ll(th_china, th_mexico, data):
    return sum([log(prob(th_china, th_mexico, w)) for w in data])

data = [c,c,m,c] # how does this graph look with all Cs?
smle.plot_mle_graph(lambda x,y: ll(x,y, data), mle(data), 
                    x_label='China',y_label='Mexico')
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1081402063529548162337249679"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1081402063529548162337249679", {"width": 432.0, "height": 288.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [0.0001, 0.9999], "ylim": [0.0001, 0.9999], "xdomain": [0.0001, 0.9999], "ydomain": [0.0001, 0.9999], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 6, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 6, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el108140206352226904", "lines": [], "paths": [], "markers": [], "texts": [{"text": "China", "position": [0.49999999999999994, -0.09657836644591611], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el108140206352410888"}, {"text": "Mexico", "position": [-0.08064516129032258, 0.49999999999999994], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el108140206351955616"}, {"text": "-5.249", "position": [0.18514196414036835, 0.8282171717171716], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -276.55181895664236, "fontsize": 10.0, "color": "#440154", "alpha": 1, "zorder": 3, "id": "el108140206351393848"}, {"text": "-4.999", "position": [0.8383161616161615, 0.011889498735225018], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -358.3513720707478, "fontsize": 10.0, "color": "#471466", "alpha": 1, "zorder": 3, "id": "el108140206351394912"}, {"text": "-4.749", "position": [0.2578899196141109, 0.5050494949494948], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -284.8288388490329, "fontsize": 10.0, "color": "#472575", "alpha": 1, "zorder": 3, "id": "el108140206351396144"}, {"text": "-4.499", "position": [0.5656434343434342, 0.061477696391984304], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -347.817181790748, "fontsize": 10.0, "color": "#453681", "alpha": 1, "zorder": 3, "id": "el108140206351446816"}, {"text": "-4.249", "position": [0.393960606060606, 0.23346110211590332], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -311.1722871761354, "fontsize": 10.0, "color": "#3F4587", "alpha": 1, "zorder": 3, "id": "el108140206351448272"}, {"text": "-3.999", "position": [0.2807813015426702, 0.8282171717171716], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -279.9264105171317, "fontsize": 10.0, "color": "#39558B", "alpha": 1, "zorder": 3, "id": "el108140206351449728"}, {"text": "-3.749", "position": [0.3039320269693463, 0.8383161616161616], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -280.58463227541756, "fontsize": 10.0, "color": "#32628D", "alpha": 1, "zorder": 3, "id": "el108140206351467632"}, {"text": "-3.499", "position": [0.9797020202020201, 0.03235411495393967], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -355.9518478400347, "fontsize": 10.0, "color": "#2C708E", "alpha": 1, "zorder": 3, "id": "el108140206351469088"}, {"text": "-3.249", "position": [0.41695589991483417, 0.5353464646464645], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -291.9493836883089, "fontsize": 10.0, "color": "#277C8E", "alpha": 1, "zorder": 3, "id": "el108140206351470488"}, {"text": "-2.999", "position": [0.5605599796122027, 0.28287171717171716], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -315.57928210208274, "fontsize": 10.0, "color": "#22898D", "alpha": 1, "zorder": 3, "id": "el108140206351508872"}, {"text": "-2.749", "positio ...

# %% [markdown]
# Solution trivial (and useless) without **constraints**

# %% [markdown]
# Constraints:
#
# * $0 \leq \paramc \leq 1 $
# * $0 \leq \paramm \leq 1 $
# * $\paramc + \paramm = 1$
#     * Isoline of $g(\paramc,\paramm)=\paramc + \paramm$

# %%
smle.plot_mle_graph(lambda x,y: ll(x,y, data), mle(data), 
                    show_constraint=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1081402064195861844258573821"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1081402064195861844258573821", {"width": 432.0, "height": 288.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [0.0001, 0.9999], "ylim": [9.999999999998899e-05, 0.9999], "xdomain": [0.0001, 0.9999], "ydomain": [9.999999999998899e-05, 0.9999], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 6, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 6, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el108140206414798920", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el108140206414874720", "color": "#1F77B4", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}], "paths": [], "markers": [], "texts": [{"text": "x", "position": [0.49999999999999994, -0.09657836644591611], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el108140206414750216"}, {"text": "y", "position": [-0.08064516129032258, 0.49999999999999994], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el108140206414881736"}, {"text": "-5.249", "position": [0.18514196414036835, 0.8282171717171716], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -276.55181895664236, "fontsize": 10.0, "color": "#440154", "alpha": 1, "zorder": 3, "id": "el108140206413936624"}, {"text": "-4.999", "position": [0.8383161616161615, 0.011889498735225018], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -358.3513720707478, "fontsize": 10.0, "color": "#471466", "alpha": 1, "zorder": 3, "id": "el108140206413938080"}, {"text": "-4.749", "position": [0.2578899196141109, 0.5050494949494948], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -284.8288388490329, "fontsize": 10.0, "color": "#472575", "alpha": 1, "zorder": 3, "id": "el108140206413980560"}, {"text": "-4.499", "position": [0.5656434343434342, 0.061477696391984304], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -347.817181790748, "fontsize": 10.0, "color": "#453681", "alpha": 1, "zorder": 3, "id": "el108140206413982016"}, {"text": "-4.249", "position": [0.393960606060606, 0.23346110211590332], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -311.1722871761354, "fontsize": 10.0, "color": "#3F4587", "alpha": 1, "zorder": 3, "id": "el108140206413983472"}, {"text": "-3.999", "position": [0.2807813015426702, 0.8282171717171716], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -279.9264105171317, "fontsize": 10.0, "color": "#39558B", "alpha": 1, "zorder": 3, "id": "el108140206414017760"}, {"text": "-3.749", "position": [0.3039320269693463, 0.8383161616161616], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -280.58463227541756, "fontsize": 10.0, "color": "#32628D", "alpha": 1, "zorder": 3, "id": "el108140206414019216"}, {"text": "-3.499", "position": [0.9797020202020201, 0.03235411495393967], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -355.9518478400347, "fontsize": 10.0, "color": "#2C708E", "alpha": 1, "zorder": 3, "id": "el108140206414020504"}, {"text": "-3.249", "position": [0.41695589991483417, 0.5353464646464645], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -291.9493836883089, "fontsize": 10.0, "color": "#277C8E", "alpha": 1, "zorder": 3, "id": "el108140206414059000"}, {"text": "-2.999", "position": [0.5605599796122027, 0.28287171717171716] ...

# %% [markdown]
# ## Gradients at Optimum

# %%
smle.plot_mle_graph(lambda x,y: ll(x,y, data), mle(data), 
                    show_constraint=True, show_optimum=True)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1081402064147991449963814306"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1081402064147991449963814306", {"width": 432.0, "height": 288.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [0.0001, 0.9999], "ylim": [9.999999999998899e-05, 0.9999], "xdomain": [0.0001, 0.9999], "ydomain": [9.999999999998899e-05, 0.9999], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 6, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 6, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el108140206354399920", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el108140206354100632", "color": "#1F77B4", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}], "paths": [], "markers": [{"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el108140206353493576pts", "facecolor": "#FF0000", "edgecolor": "#FF0000", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 3.0], [0.7956093000000001, 3.0], [1.5587396123545605, 2.683901074764725], [2.121320343559643, 2.121320343559643], [2.683901074764725, 1.5587396123545605], [3.0, 0.7956093000000001], [3.0, 0.0], [3.0, -0.7956093000000001], [2.683901074764725, -1.5587396123545605], [2.121320343559643, -2.121320343559643], [1.5587396123545605, -2.683901074764725], [0.7956093000000001, -3.0], [0.0, -3.0], [-0.7956093000000001, -3.0], [-1.5587396123545605, -2.683901074764725], [-2.121320343559643, -2.121320343559643], [-2.683901074764725, -1.5587396123545605], [-3.0, -0.7956093000000001], [-3.0, 0.0], [-3.0, 0.7956093000000001], [-2.683901074764725, 1.5587396123545605], [-2.121320343559643, 2.121320343559643], [-1.5587396123545605, 2.683901074764725], [-0.7956093000000001, 3.0], [0.0, 3.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}], "texts": [{"text": "x", "position": [0.49999999999999994, -0.09657836644591611], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el108140206354347848"}, {"text": "y", "position": [-0.08064516129032258, 0.49999999999999994], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el108140206354047552"}, {"text": "-5.249", "position": [0.18514196414036835, 0.8282171717171716], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -276.55181895664236, "fontsize": 10.0, "color": "#440154", "alpha": 1, "zorder": 3, "id": "el108140206353526344"}, {"text": "-4.999", "position": [0.8383161616161615, 0.011889498735225018], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -358.3513720707478, "fontsize": 10.0, "color": "#471466", "alpha": 1, "zorder": 3, "id": "el108140206353568880"}, {"text": "-4.749", "position": [0.2578899196141109, 0.5050494949494948], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -284.8288388490329, "fontsize": 10.0, "color": "#472575", "alpha": 1, "zorder": 3, "id": "el108140206353570336"}, {"text": "-4.499", "position": [0.5656434343434342, 0.061477696391984304], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -347.817181790748, "fontsize": 10.0, "color": "#453681", "alpha": 1, "zorder": 3, "id": "el108140206353571792"}, {"text": "-4.249", "position": [0.393960606060606, 0.23346110211590332], "coordinates": "data", "h_anchor": "middle", "v_baseline": "central", "rotation": -311.1722871761354, "fontsize": 10.0, "color": "#3F4587", "alpha": 1, "zorder": 3, "id": "el108140206353606080"}, {"text": "-3.999", "position": [0.2807813015426702, 0.8282171717171716], "coordinates": "data", "h_ancho ...

# %% [markdown]
# $$
# \nabla_\params l(\params) = \alpha \nabla_\params g(\params)
# $$

# %% [markdown]
# $$
# l(\params)  = \countc  \log \paramc +  \countm \log \paramm
# $$

# %% [markdown]
# $$
# \frac{\partial l(\params)}{\partial \paramc} = \frac{\counts{D}{China}}{\paramc}
# $$

# %% [markdown]
# $$
# g(\params) = \paramc + \paramm
# $$

# %% [markdown]
# $$
# \frac{\partial g(\params)}{\partial \paramc} = 1
# $$

# %% [markdown]
# $$
# \frac{\partial l(\params)}{\partial \paramc} = \alpha \frac{\partial g(\params)}{\partial \paramc}
# $$

# %% [markdown]
# $$
# \frac{\countc}{\paramc} = \alpha
# $$

# %% [markdown]
# $$
# \paramc = \frac{\countc}{\alpha} = \ldots
# $$
# $$
# \paramm = \frac{\countm}{\alpha} = \ldots
# $$

# %% [markdown]
# $$
# \paramc = \frac{\countc}{\countc + \countm}
# $$

# %% [markdown]
# ## Summary
#
# * Derive MLE by
#     * equating loss and constraint gradient
#     * using constraint equation
# * Easy to extend to any discrete generative model with conditional probability tables
# * Learning goal: be able to derive the equation for new models

# %% [markdown]
# ## Background Material
# * Introduction to MLE in [Mike Collin's notes](http://www.cs.columbia.edu/~mcollins/em.pdf)
