"id":"24e364ac-fc27-4945-9fe1-d26784fc60b0","type":"Grid"},{"id":"f6fdff31-754c-48ec-bbb4-3db46241cdca","type":"LinearAxis"},{"id":"97ee2ee7-c386-4c21-92a2-60935200760e","type":"Grid"},{"id":"05b2d50e-4000-40a8-8d62-76281e2f9944","type":"BoxAnnotation"},{"id":"d4952a02-1928-4fd8-bcba-691a5162af72","type":"Legend"},{"id":"9fc7b21e-af69-43c2-bd30-0f0f5c4e072f","type":"GlyphRenderer"}],"title":"simple line example","tool_events":{"id":"35b28459-aae6-4083-bcc9-baff0ae5159e","type":"ToolEvents"},"tools":[{"id":"e6a9a483-7992-4eb1-aa58-0b4443834772","type":"PanTool"},{"id":"58aebcf7-ff3a-479e-8d62-635806f33c77","type":"WheelZoomTool"},{"id":"4b7e62e4-dd3d-4eff-8b74-84cca78cd7fa","type":"BoxZoomTool"},{"id":"421dc3e5-df81-493d-973a-ce3a6990fde0","type":"PreviewSaveTool"},{"id":"f185d6e2-fc6e-4f0e-810f-884e0b8db823","type":"ResizeTool"},{"id":"dfb18370-cf06-49cb-9d3d-32bd0ea3ac53","type":"ResetTool"},{"id":"e07e442a-11d7-4ccb-9807-d18fe053a9b6","type":"HelpTool"}],"x_range":{"id":"2d946646-a77b-454a-a7f1-01068f3d214a","type":"DataRange1d"},"y_range":{"id":"a60509e9-d78c-425d-b7fb-0f8c0cd3a06e","type":"DataRange1d"}},"id":"e2feb26e-166d-44d7-aff1-ba3d68aedb72","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"e2feb26e-166d-44d7-aff1-ba3d68aedb72","subtype":"Figure","type":"Plot"},"ticker":{"id":"c2a3276e-0f1d-4e78-9b5b-0c4a323b87b0","type":"BasicTicker"}},"id":"97ee2ee7-c386-4c21-92a2-60935200760e","type":"Grid"},{"attributes":{"overlay":{"id":"05b2d50e-4000-40a8-8d62-76281e ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %%
[(1,2)] * 5
# Out:
# [(1, 2), (1, 2), (1, 2), (1, 2), (1, 2)]

# %%
"(Bush|||Russia)".split("|||")
# Out:
# ['(Bush', 'Russia)']

# %%
import re
re.split("\|\|\||\(|\)", "(Bush|||Russia)")
# Out:
# ['', 'Bush', 'Russia', '']

# %%
re.split("z=$", "(Bush|||Russia)")
# Out:
# ['(Bush|||Russia)']

# %%
import tikzmagic

# %%
# %%tikz
# \tikzset{every node/.style={font=\sffamily,white}}
#
# \node[fill=red] at (0,0) (a) {Can I make this $\sum$ longer?};
# \node[fill=blue] at (3,1) (b) {That};
# \node[fill=blue] at (0,-1) (c) {This};
# \draw[->] (a) edge (b) (a) edge (c);

# %% [markdown]
# $\operatorname{sgn}$
