id":"0d7daf23-7ae4-4d62-8047-94845eb6e327","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"2736cfb2-ec37-482f-9cf9-dcb7914659f8","type":"BasicTicker"},{"attributes":{"plot":{"id":"0d7daf23-7ae4-4d62-8047-94845eb6e327","subtype":"Figure","type":"Plot"}},"id":"d05bcc38-2d8b-4106-85de-7898ae7aeca0","type":"PanTool"},{"attributes":{},"id":"1eec8c9e-291c-408f-a6 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
[(1,2)] * 5
# Out:
# [(1, 2), (1, 2), (1, 2), (1, 2), (1, 2)]

# %%
"(Bush|||Russia)".split("|||")
# Out:
# ['(Bush', 'Russia)']

# %%
import re
re.split("\|\|\||\(|\)", "(Bush|||Russia)")
# Out:
# ['', 'Bush', 'Russia', '']

# %%
re.split("z=$", "(Bush|||Russia)")
# Out:
# ['(Bush|||Russia)']

# %%
import tikzmagic

# %%
# %%tikz
# \tikzset{every node/.style={font=\sffamily,white}}
#
# \node[fill=red] at (0,0) (a) {Can I make this $\sum$ longer?};
# \node[fill=blue] at (3,1) (b) {That};
# \node[fill=blue] at (0,-1) (c) {This};
# \draw[->] (a) edge (b) (a) edge (c);

# %%
# %%tikz
# \input{../fig/test.tex}

# %%
import pandas as pd
pd.DataFrame([('Ab',1),('C',2),('asdasd',2)], columns=['Name', 'Age'])
# Out:
#      Name  Age
# 0      Ab    1
# 1       C    2
# 2  asdasd    2

# %%
# %%latex
# \usepackage{algorithm}
# \begin{algorithmic}
# \If {$i\geq maxval$}
#     \State $i\gets 0$
# \Else
#     \If {$i+k\leq maxval$}
#         \State $i\gets i+k$
#     \EndIf
# \EndIf
# \end{algorithmic}
# Out:
# \usepackage{algorithm}
# \begin{algorithmic}
# \If {$i\geq maxval$}
#     \State $i\gets 0$
# \Else
#     \If {$i+k\leq maxval$}
#         \State $i\gets i+k$
#     \EndIf
# \EndIf
# \end{algorithmic}

# %% [markdown]
# $\operatorname{sgn}$

# %% [markdown]
# ![img](../fig/fig.png)
#
#  Right     Left     Center     Default
# -------     ------ ----------   -------
#      12     12        12            12
#     123     123       123          123
#       1     1          1             1

# %%
# util.Table([["\sum"]])
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
# Out:
# <h1>Hello, world!</h1>

# %%
import statnlpbook.word_mt as word_mt

word_mt.Alignment("NULL 音楽 が 好き".split(" "),
                  "I like music".split(" "),
                  [(0,0),(1,2),(3,1)])

# "NULL 音楽 が 好き".split(" ")
# Out:
#         <svg id='db918b8c-b24e-11e6-83e6-a0999b02cfbb' xmlns="http://www.w3.org/2000/svg"
#              xmlns:xlink="http://www.w3.org/1999/xlink"
#              viewBox="0 0 400 100"
#              >
#
#             <text x="0" y="20" class="source">
#                 <tspan id='t0'>NULL</tspan> <tspan id='t1'>音楽</tspan> <tspan id='t2'>が</tspan> <tspan id='t3'>好き</tspan>
#             </text>
#             <text x="0" y="95" class="target">
#                 <tspan id='t0'>I</tspan> <tspan id='t1'>like</tspan> <tspan id='t2'>music</tspan>
#             </text>
#             <g class='connections'></g>
#             <script>
#               $(function() {
#                   root = $(document.getElementById('db918b8c-b24e-11e6-83e6-a0999b02cfbb'));
#                   root.find('.connections').empty();
#                   alignments = [['.source #t0','.target #t0',1.0],['.source #t1','.target #t2',1.0],['.source #t3','.target #t1',1.0]];
#                   function appendLine(alignment) {
#                       s1 = root.find(alignment[0])[0];
#                       x1 = s1.getExtentOfChar(0).x + s1.getComputedTextLength() / 2.0;
#                       y1 = s1.getExtentOfChar(0).y + s1.getExtentOfChar(0).height;
#                       s2 = root.find(alignment[1])[0];
#                       x2 = s2.getExtentOfChar(0).x + s2.getComputedTextLength() / 2.0;
#                       y2 = s2.getExtentOfChar(0).y;
#                       var newLine = document.createElementNS('http://www.w3.org/2000/svg','line');
#                       var score = alignment[2];
#                       newLine.setAttribute('x1',x1.toString());
#                       newLine.setAttribute('y1',y1.toString());
#                       newLine.setAttribute('x2',x2.toString());
#                       newLine.setAttribute('y2',y2.toString());
#                       newLine.setAttribute('style',"stroke:black;stroke-width:2;stroke-opacity:" + score + ";");
#                       root.find('.connections').append(newLine)
#                   };
#                   //console.log(alignments);
#                   for (var i = 0; i < alignments.length; i++) {
#                     appendLine(alignments[i]);
#                   }
#                   //console.log($(root).find('.connections'));
#               });
#             </script>
#         </svg>

# %%
import statnlpbook.transition as transition
   
arcs = [
    { 'dir': 'right', 'end': 1, 'label': 'vmod', 'start': 0 }
]
words = [
    { 'tag': 'UH', 'text': 'Hello' },
    { 'tag': 'NNP', 'text': 'Blah.' },    
     
]
transition.DependencyTree(arcs, words)
# Out:
#     <div id='displacy0' style="overflow: scroll; width: 5000px;"></div>
#     <script>
#     $(function() {
#     requirejs.config({
#         paths: {
#             'displaCy': ['/files/node_modules/displacy/displacy'],
#                                                   // strip .js ^, require adds it back
#         },
#     });
#     require(['displaCy'], function() {
#         console.log("Loaded :)");
#         const displacy = new displaCy('http://localhost:8000', {
#             container: '#displacy0',
#             format: 'spacy',
#             distance: 150,
#             offsetX: 0,
#             wordSpacing: 20,
#             arrowSpacing: 3,
#
#         });
#         const parse = {
#             arcs: [{"dir": "right", "end": 1, "label": "vmod", "start": 0}],
#             words: [{"tag": "UH", "text": "Hello"}, {"tag": "NNP", "text": "Blah."}]
#         };
#
#         displacy.render(parse, {
#             uniqueId: 'render_displacy0'
#             //color: '#ff0000'
#         });
#         return {};
#     });
#     });
#     </script>

# %%
transition.DependencyTree(arcs, words)
# Out:
#     <div id='displacy2' style="overflow: scroll; width: 5000px;"></div>
#     <script>
#     $(function() {
#     requirejs.config({
#         paths: {
#             'displaCy': ['/files/node_modules/displacy/displacy'],
#                                                   // strip .js ^, require adds it back
#         },
#     });
#     require(['displaCy'], function() {
#         console.log("Loaded :)");
#         const displacy = new displaCy('http://localhost:8000', {
#             container: '#displacy2',
#             format: 'spacy',
#             distance: 150,
#             offsetX: 0,
#             wordSpacing: 20,
#             arrowSpacing: 3,
#
#         });
#         const parse = {
#             arcs: [{"dir": "right", "end": 1, "label": "vmod", "start": 0}],
#             words: [{"tag": "UH", "text": "Hello"}, {"tag": "NNP", "text": "Blah."}]
#         };
#
#         displacy.render(parse, {
#             uniqueId: 'render_displacy2'
#             //color: '#ff0000'
#         });
#         return {};
#     });
#     });
#     </script>

# %%
import statnlpbook.draw as draw 

draw.edit_svg("blah")
# Out:
#     <div>
#     <svg width="800" height="600" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="400" cy="300" r="300"/>
#       <foreignObject x="100" y="100" width="1400" height="1400">
#         <div xmlns="http://www.w3.org/1999/xhtml" style="font-family:Times; font-size:15px">
#         $\sum_i i^2$
#         </div>
#       </foreignObject>
#     </svg>
#     <script>
#         //xhr = new XMLHttpRequest();
#         //xhr.open("GET","my.svg",false);
#         // Following line is just to be on the safe side;
#         // not needed if your server delivers SVG with correct MIME type
#         //xhr.overrideMimeType("image/svg+xml");
#         //xhr.send("");
#         //document.getElementById("svgContainer")
#         //  .appendChild(xhr.responseXML.documentElement);
#     </script>
