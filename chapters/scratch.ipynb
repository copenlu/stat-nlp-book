","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3a37d1ee-9293-45fa-a1ff-3ba665fedd54","type":"Line"},{"attributes":{"below":[{"id":"e5d30617-0c6b-4560-89bf-0dcf09049cdc","type":"LinearAxis"}],"left":[{"id":"1417fe4c-8913-47b1-aa70-a3fa6eceafbf","type":"LinearAxis"}],"renderers":[{"id":"e5d30617-0c6b-4560-89bf-0dcf09049cdc","type":"LinearAxis"},{"id":"fea30217-16f4-4baf-b9fe-1e41ff367920","type":"Grid"},{"id":"1417fe4c-8913-47b1-aa70-a3fa6eceafbf","type":"LinearAxis"},{"id":"cdbb4ecc-6ec9-493d-8d74-4d9015dec0ce","type":"Grid"},{"id":"268d6fa1-43bb-42c3-bca4-63ff5c72b8e9","type":"BoxAnnotation"},{"id":"0be21164-3584-4676-a2a3-3c13d56f4668","type":"Legend"},{"id":"12eb903e-9407-4114-9c6e-c6b04a42902b","type":"GlyphRenderer"}],"title":"simple line example","tool_events":{"id":"eb29d5c6-7be2-4a7c-9ccb-a9dd44e5294d","type":"ToolEvents"},"tools":[{"id":"d1e4b669-9a11-470a-bdc0-98fde6f3e069","type":"PanTool"},{"id":"cf37b2dc-a5ee-47fb-ade7-ca075cb19035","type":"WheelZoomTool"},{"id":"800dd8d6-6403-44b3-b769-2e2a89eaa411","type":"BoxZoomTool"},{"id":"4f525475-187c-4d32-baf0-9d5011456030","type":"PreviewSaveTool"},{"id":"162ac0b1-df36-42e4-b8d9-07a336c635fa","type":"ResizeTool"},{"id":"81845abd-b7bb-47bc-973a-2c8e16c5476e","type":"ResetTool"},{"id":"726697a7-a8de-4ed0-98ea-6d19ba0f048d","type":"HelpTool"}],"x_range":{"id":"43d614ec-d3a5-41fd-992e-650bc466b876","type":"DataRange1d"},"y_range":{"id":"16498a69-3867-4dcf-9e49-efd72 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %%
[(1,2)] * 5
# Out:
# [(1, 2), (1, 2), (1, 2), (1, 2), (1, 2)]

# %%
"(Bush|||Russia)".split("|||")
# Out:
# ['(Bush', 'Russia)']

# %%
import re
re.split("\|\|\||\(|\)", "(Bush|||Russia)")
# Out:
# ['', 'Bush', 'Russia', '']

# %%
re.split("z=$", "(Bush|||Russia)")
# Out:
# ['(Bush|||Russia)']

# %%
import tikzmagic

# %%
# %%tikz
# \tikzset{every node/.style={font=\sffamily,white}}
#
# \node[fill=red] at (0,0) (a) {Can I make this $\sum$ longer?};
# \node[fill=blue] at (3,1) (b) {That};
# \node[fill=blue] at (0,-1) (c) {This};
# \draw[->] (a) edge (b) (a) edge (c);

# %%
# %%tikz
# \input{../fig/test.tex}

# %%
import pandas as pd
pd.DataFrame([('Ab',1),('C',2),('asdasd',2)], columns=['Name', 'Age'])
# Out:
#      Name  Age
# 0      Ab    1
# 1       C    2
# 2  asdasd    2

# %% [markdown]
# $\operatorname{sgn}$
