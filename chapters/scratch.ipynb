# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
from graphviz import Digraph
sys.path.append("..")
import statnlpbook.util as util

# %%
from graphviz import Digraph

dot = Digraph(comment='The Round Table')

dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
# dot.edge('B', 'L', constraint='true')

dot

# %%
from bokeh.plotting import figure, output_notebook, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 1]

# output to static HTML file
output_notebook()

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
# Out:
# /usr/local/lib/python3.5/site-packages/pandas/__init__.py:7: DeprecationWarning: bad escape \s
#   from pandas import hashtable, tslib, lib
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="15882ce4-e254-409b-9602-eb740ff896fb">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="3a160a57-e180-44cc-bfcb-edf706d806a0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3a160a57-e180-44cc-bfcb-edf706d806a0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3a160a57-e180-44cc-bfcb-edf706d806a0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"fd731860-8baf-45c1-b771-2daa18928228":{"roots":{"references":[{"attributes":{"plot":{"id":"0bc52d79-c2b6-4226-80ee-cf09e4cef3b4","subtype":"Figure","type":"Plot"}},"id":"90b83026-dddc-450d-bd40-58538caa4a04","type":"PanTool"},{"attributes":{"overlay":{"id":"b2dd8b69-e72d-4678-996a-9a7039cb73a6","type":"BoxAnnotation"},"plot":{"id":"0bc52d79-c2b6-4226-80ee-cf09e4cef3b4","subtype":"Figure","type":"Plot"}},"id":"1a62973a-c11d-4816-a04d-e39189a2fea1","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"0bc52d79-c2b6-4226-80ee-cf09e4cef3b4","subtype":"Figure","type":"Plot"}},"id":"de1c2a18-c9a6-4c13-a17f-6fc078fb2b8d","type":"PreviewSaveTool"},{"attributes":{"callback":null},"id":"04e96844-76e1-438b-9261-c17b4214981c","type":"DataRange1d"},{"attributes":{"legends":[["Temp.",[{"id":"04394710-57b1-4b1a-979d-bc09fbd459dc","type":"GlyphRenderer"}]]],"plot":{"id":"0bc52d79-c2b6-4226-80ee-cf09e4cef3b4","subtype":"Figure","type":"Plot"}},"id":"757aa4d2-7ada-4646-87c4-b9fb4e0f818d","type":"Legend"},{"attributes":{},"id":"1d9ab389-8731-47f9-89fb-6389e1934155","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"0bc52d79-c2b6-4226-80ee-cf09e4cef3b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f5b2fab-6581-4191-93e2-cb84255131bf","type":"BasicTicker"}},"id":"e31722b4-2bd5-4181-ac22-84c82630c3cb","type":"Grid"},{"attributes":{"plot":{"id":"0bc52d79-c2b6-4226-80ee-cf09e4cef3b4","subtype":"Figure","type":"Plot"}},"id":"b702dbbe-a13e-44ce-8516-667f9bba8d51","type":"ResetTool"},{"attributes":{"callback":null},"id":"4736877d-afee-4003-ab51-32948f559a85","type":"DataRange1d"},{"attributes":{},"id":"6f5b2fab-6581-4191-93e2-cb84255131bf","type":"BasicTicker"},{"attributes":{"plot":{"id":"0bc52d79-c2b6-4226-80ee-cf09e4cef3b4","subtype":"Figure","type":"Plot"}},"id":"24190efc-e6bb-447b-b261-e07b78cf06f1","type":"HelpTool"},{"attributes":{"data_source":{"id":"5080b7ef-6090-4370-8382-218d49040910","type":"ColumnDataSource"},"glyph":{"id":"d06a5824-948e-478f-8ee3-9309b49fcd52","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"5d8143b1-c2b7-475c-bf30-d7eee85b9820","type":"Line"},"selection_glyph":null},"id":"04394710-57b1-4b1a-979d-bc09fbd459dc","type":"GlyphRenderer"},{"attributes":{},"id":"2c1a705d-33db-4575-b1e5-e7fe2c470323","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0bc52d79-c2b6-4226-80ee-cf09e4cef3b4","subtype":"Figure","type":"Plot"}},"id":"c1334fd2-eb7a-43af-83f1-02c5e0852c87","type":"ResizeTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"d06a5824-948e-478f-8ee3-9309b49fcd52","type":"Line"},{"attributes":{"plot":{"id":"0bc52d79-c2b6-4226-80ee-cf09e4cef3b4","subtype":"Figure","type":"Plot"}},"id":"8790f1a8-068f-4b1b-8a74-1c85351ddb92","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"b0c982ea-8d1c-4cc5-bdfe-a85262c33bdb","type":"LinearAxis"}],"left":[{"id":"36abf0cf-26b2-40c5-87f5-c0cb60b59087","type":"LinearAxis"}],"renderers":[{"id":"b0c982ea-8d1c-4cc5-bdfe-a85262c33bdb","type":"LinearAxis"},{"id":"67694ef5-fabd-452f-98f7-4bb77c25bcaa","type":"Grid"},{"id":"36abf0cf-26b2-40c5-87f5-c0cb60b59087","type":"LinearAxis"},{"id":"e31722b4-2bd5-4181-ac22-84c82630c3cb","type":"Grid"},{"id":"b2dd8b69-e72d-4678-996a-9a7039cb73a6","type":"BoxAnnotation"},{"id":"757aa4d2-7ada-4646-87c4-b9fb4e0f818d","type":"Legend"},{"id":"04394710-57b1-4b1a-979d-bc09fbd459dc","type":"GlyphRenderer"}],"title":"simple line example","tool_events":{"id":"c481c13f-42a4-437b-a130-3d89d60617ab","type":"ToolEvents"},"tools":[{"id":"90b83026-dddc-450d-bd40-58538caa4a04","type":"PanTool"},{"id":"8790f1a8-068f-4b1b-8a74-1c85351ddb92","type":"WheelZoomTool"},{"id":"1a62973a-c11d-4816-a04d-e39189a2fea1","type":"BoxZoomTool"},{"id":"de1c2a18-c9a6-4c13-a17f-6fc078fb2b8d","type":"PreviewSaveTool"},{"id":"c1334fd2-eb7a-43af-83f1-02c5e0852c87","type":"ResizeTool"},{"id":"b702dbbe-a13e-44ce-8516-667f9bba8d51","type":"ResetTool"},{"id":"24190efc- ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
[(1,2)] * 5
# Out:
# [(1, 2), (1, 2), (1, 2), (1, 2), (1, 2)]

# %%
"(Bush|||Russia)".split("|||")
# Out:
# ['(Bush', 'Russia)']

# %%
import re
re.split("\|\|\||\(|\)", "(Bush|||Russia)")
# Out:
# ['', 'Bush', 'Russia', '']

# %%
re.split("z=$", "(Bush|||Russia)")
# Out:
# ['(Bush|||Russia)']

# %%
import tikzmagic

# %%
# %%tikz
# \tikzset{every node/.style={font=\sffamily,white}}
#
# \node[fill=red] at (0,0) (a) {Can I make this $\sum$ longer?};
# \node[fill=blue] at (3,1) (b) {That};
# \node[fill=blue] at (0,-1) (c) {This};
# \draw[->] (a) edge (b) (a) edge (c);

# %%
# %%tikz
# \input{../fig/test.tex}

# %%
import pandas as pd
pd.DataFrame([('Ab',1),('C',2),('asdasd',2)], columns=['Name', 'Age'])
# Out:
#      Name  Age
# 0      Ab    1
# 1       C    2
# 2  asdasd    2

# %%
# %%latex
# \usepackage{algorithm}
# \begin{algorithmic}
# \If {$i\geq maxval$}
#     \State $i\gets 0$
# \Else
#     \If {$i+k\leq maxval$}
#         \State $i\gets i+k$
#     \EndIf
# \EndIf
# \end{algorithmic}
# Out:
# \usepackage{algorithm}
# \begin{algorithmic}
# \If {$i\geq maxval$}
#     \State $i\gets 0$
# \Else
#     \If {$i+k\leq maxval$}
#         \State $i\gets i+k$
#     \EndIf
# \EndIf
# \end{algorithmic}

# %% [markdown]
# $\operatorname{sgn}$

# %% [markdown]
# ![img](../fig/fig.png)
#
#  Right     Left     Center     Default
# -------     ------ ----------   -------
#      12     12        12            12
#     123     123       123          123
#       1     1          1             1

# %%
# util.Table([["\sum"]])
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
# Out:
# <h1>Hello, world!</h1>

# %%
import statnlpbook.word_mt as word_mt

word_mt.Alignment("NULL 音楽 が 好き".split(" "),
                  "I like music".split(" "),
                  [(0,0),(1,2),(3,1)])

# "NULL 音楽 が 好き".split(" ")
# Out:
#         <svg id='ce54604c-b55e-11e6-b16e-a0999b02cfbb' xmlns="http://www.w3.org/2000/svg"
#              xmlns:xlink="http://www.w3.org/1999/xlink"
#              viewBox="0 0 400 100"
#              >
#
#             <text x="0" y="20" class="source">
#                 <tspan id='t0'>NULL</tspan> <tspan id='t1'>音楽</tspan> <tspan id='t2'>が</tspan> <tspan id='t3'>好き</tspan>
#             </text>
#             <text x="0" y="95" class="target">
#                 <tspan id='t0'>I</tspan> <tspan id='t1'>like</tspan> <tspan id='t2'>music</tspan>
#             </text>
#             <g class='connections'></g>
#             <script>
#               $(function() {
#                   root = $(document.getElementById('ce54604c-b55e-11e6-b16e-a0999b02cfbb'));
#                   root.find('.connections').empty();
#                   alignments = [['.source #t0','.target #t0',1.0],['.source #t1','.target #t2',1.0],['.source #t3','.target #t1',1.0]];
#                   function appendLine(alignment) {
#                       s1 = root.find(alignment[0])[0];
#                       x1 = s1.getExtentOfChar(0).x + s1.getComputedTextLength() / 2.0;
#                       y1 = s1.getExtentOfChar(0).y + s1.getExtentOfChar(0).height;
#                       s2 = root.find(alignment[1])[0];
#                       x2 = s2.getExtentOfChar(0).x + s2.getComputedTextLength() / 2.0;
#                       y2 = s2.getExtentOfChar(0).y;
#                       var newLine = document.createElementNS('http://www.w3.org/2000/svg','line');
#                       var score = alignment[2];
#                       newLine.setAttribute('x1',x1.toString());
#                       newLine.setAttribute('y1',y1.toString());
#                       newLine.setAttribute('x2',x2.toString());
#                       newLine.setAttribute('y2',y2.toString());
#                       newLine.setAttribute('style',"stroke:black;stroke-width:2;stroke-opacity:" + score + ";");
#                       root.find('.connections').append(newLine)
#                   };
#                   //console.log(alignments);
#                   for (var i = 0; i < alignments.length; i++) {
#                     appendLine(alignments[i]);
#                   }
#                   //console.log($(root).find('.connections'));
#               });
#             </script>
#         </svg>

# %%
import statnlpbook.transition as transition
   
arcs = [
    { 'dir': 'right', 'end': 1, 'label': 'vmod', 'start': 0 }
]
words = [
    { 'tag': 'UH', 'text': 'Hello' },
    { 'tag': 'NNP', 'text': 'Blah.' },    
     
]
transition.DependencyTree(arcs, words)
# Out:
#     <div id='displacy0' style="overflow: scroll; width: 5000px;"></div>
#     <script>
#     $(function() {
#     requirejs.config({
#         paths: {
#             'displaCy': ['/files/node_modules/displacy/displacy'],
#                                                   // strip .js ^, require adds it back
#         },
#     });
#     require(['displaCy'], function() {
#         console.log("Loaded :)");
#         const displacy = new displaCy('http://localhost:8000', {
#             container: '#displacy0',
#             format: 'spacy',
#             distance: 150,
#             offsetX: 0,
#             wordSpacing: 20,
#             arrowSpacing: 3,
#
#         });
#         const parse = {
#             arcs: [{"dir": "right", "start": 0, "end": 1, "label": "vmod"}],
#             words: [{"text": "Hello", "tag": "UH"}, {"text": "Blah.", "tag": "NNP"}]
#         };
#
#         displacy.render(parse, {
#             uniqueId: 'render_displacy0'
#             //color: '#ff0000'
#         });
#         return {};
#     });
#     });
#     </script>

# %%
transition.DependencyTree(arcs, words)
# Out:
#     <div id='displacy1' style="overflow: scroll; width: 5000px;"></div>
#     <script>
#     $(function() {
#     requirejs.config({
#         paths: {
#             'displaCy': ['/files/node_modules/displacy/displacy'],
#                                                   // strip .js ^, require adds it back
#         },
#     });
#     require(['displaCy'], function() {
#         console.log("Loaded :)");
#         const displacy = new displaCy('http://localhost:8000', {
#             container: '#displacy1',
#             format: 'spacy',
#             distance: 150,
#             offsetX: 0,
#             wordSpacing: 20,
#             arrowSpacing: 3,
#
#         });
#         const parse = {
#             arcs: [{"dir": "right", "start": 0, "end": 1, "label": "vmod"}],
#             words: [{"text": "Hello", "tag": "UH"}, {"text": "Blah.", "tag": "NNP"}]
#         };
#
#         displacy.render(parse, {
#             uniqueId: 'render_displacy1'
#             //color: '#ff0000'
#         });
#         return {};
#     });
#     });
#     </script>

# %%
import statnlpbook.draw as draw 

draw.edit_svg("blah")
# Out:
#     <div>
#     <svg width="800" height="600" xmlns="http://www.w3.org/2000/svg">
#       <!-- <circle cx="400" cy="300" r="300"/> -->
#       <foreignObject x="100" y="100" width="400" height="400">
#         <div xmlns="http://www.w3.org/1999/xhtml" style="font-family:Times; font-size:15px">
#         $\sum_i i^2$
#         </div>
#       </foreignObject>
#     </svg>
#     <script>
#         $.get("draw/12", function(data, status){
#             alert("Data: " + data + "
# Status: " + status);
#         });
#         //xhr = new XMLHttpRequest();
#         //xhr.open("GET","my.svg",false);
#         // Following line is just to be on the safe side;
#         // not needed if your server delivers SVG with correct MIME type
#         //xhr.overrideMimeType("image/svg+xml");
#         //xhr.send("");
#         //document.getElementById("svgContainer")
#         //  .appendChild(xhr.responseXML.documentElement);
#     </script>
